# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

model = init_chat_model("groq:llama-3.3-70b-versatile")
# Out:
# Why did the banker decide to quit his job and become a baker?
#
# Because he wanted to make some real dough, and not just a lot of interest in people's lives.

# %%
from langchain.tools import tool
@tool
def get_weather(location: str) -> str:
    """Get the weather for a given location."""
    return f"The weather at {location} is sunny."
model_with_tools=model.bind_tools([get_weather])

# %%
response=model_with_tools.invoke("what is the weather of Kathmandu")
response
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '06s7hxbdq', 'function': {'arguments': '{"location":"Kathmandu"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 222, 'total_tokens': 239, 'completion_time': 0.036824263, 'completion_tokens_details': None, 'prompt_time': 0.011686284, 'prompt_tokens_details': None, 'queue_time': 0.159776265, 'total_time': 0.048510547}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019dfe38-82fd-7db1-85d3-a9e60d04fbb5-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Kathmandu'}, 'id': '06s7hxbdq', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 222, 'output_tokens': 17, 'total_tokens': 239})
